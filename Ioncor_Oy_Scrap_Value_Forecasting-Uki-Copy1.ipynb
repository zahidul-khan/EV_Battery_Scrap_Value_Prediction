# %% [markdown]
# # ![Ioncor.jpg](attachment:d291ad74-6c12-4314-b3b0-c870c2f0d1d7.jpg) IONCOR Oy Scrap Value Forecasting Dashboard (Random Forest Regressor,XGBoost, ARIMA, LSTM, Prophet)

# %% [markdown]
# ## 📦 Import, Load libraries and packages

# %%
import nbformat
from pathlib import Path

# %% [markdown]
# ## 📁 Uploaded Files and Setup

# %%
# Load all uploaded notebooks
notebook_paths = [
    "Ioncor_Oy_Scrap_Value_Forecasting-1.ipynb"
    "Ioncor_Oy_Scrap_Value_Forecasting-2.ipynb",
    "Ioncor_Oy_Scrap_Value_Forecasting-3.ipynb",
    "Ioncor_Oy_Scrap_Value_Forecasting-Uki.ipynb"
]

# %% [markdown]
# ## ⚙️ Define Files and Preprocessing Function

# %%
# Function to extract code cells
def extract_code_cells(notebook_path):
    with open(notebook_path, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)
    code_cells = [cell['source'] for cell in nb.cells if cell.cell_type == 'code']
    return code_cells

# %% [markdown]
# ## 🔁 Extract code cells

# %%
all_code_cells = {}
for path in notebook_paths:
    name = Path(path).stem
    all_code_cells[name] = extract_code_cells(path)

all_code_cells.keys()  # Show the loaded notebook names
Result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 for path in notebook_paths:
#       3     name = Path(path).stem
# ----> 4     all_code_cells[name] = extract_code_cells(path)
#       6 all_code_cells.keys()  # Show the loaded notebook names
#       7 Result
#
# Cell In[8], line 3, in extract_code_cells(notebook_path)
#       2 def extract_code_cells(notebook_path):
# ----> 3     with open(notebook_path, 'r', encoding='utf-8') as f:
#       4         nb = nbformat.read(f, as_version=4)
#       5     code_cells = [cell['source'] for cell in nb.cells if cell.cell_type == 'code']
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
# ...

# %%
## 🧠 Analising the code cells

# %%
# Show a preview of the first few code cells from each notebook to understand the content
preview_cells = {
    name: cells[:5]  # Preview first 5 code cells from each notebook
    for name, cells in all_code_cells.items()
}

preview_cells
